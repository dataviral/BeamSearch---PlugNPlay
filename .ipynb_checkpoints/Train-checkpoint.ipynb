# %%
from utils import get_data, Dataset, index2Sent, collate_fn_train, collate_fn_test

# %% [markdown]
# ## Load Data

# %%
DATA_PATH = "data/news_summary.csv"

# %%
NUM_WORDS = 10000
MAX_TEXT_LEN = 500
MAX_SUM_LEN = 100

# %%
data, w2i, i2w = get_data(DATA_PATH, NUM_WORDS)
# Out:
# Length of the data: 4514
# Length of the data after dropping nan: 4396

# %%
dataset = Dataset(data, w2i, MAX_TEXT_LEN, MAX_SUM_LEN, isTrain=True)

# %% [markdown]
# # Train

# %%
from Seq2Seq import Seq2Seq
import torch
import torch.nn as nn

# %%
VOCAB_SIZE = NUM_WORDS + 4
EMBEDDING_DIM = 50
HIDDEN_DIM = 128
BATCH_SIZE = 12
DEVICE = 'cuda'

# %%
dataloader = torch.utils.data.DataLoader(dataset, BATCH_SIZE, num_workers=8, shuffle=True, collate_fn=collate_fn_train)

# %%
model = Seq2Seq(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM).to(DEVICE)
criterion = nn.CrossEntropyLoss(reduction='none')
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
for i in range(10):
    total_loss = 0.
    for batch_num, ((x, xlens), (y, ylens)) in enumerate(dataloader):

        # setup tensors
        x = x.long().to(DEVICE)
        y = y.long().to(DEVICE)
        
#         print(x.size(), y.size())
        
        # clear previous gradients
        optimizer.zero_grad()

        # generate predictions
        # output: (BATCH_SIZE, time_steps, NUM_WORDS)
        output = model(x, xlens, y)

        ### Calculate Loss
        # 1. y must be shifted by 1 for loss calc. since outputs should not not contain <sos>
        y_true = torch.cat([y[:, 1:], torch.ones((y.size(0), 1)).long().to(DEVICE) * w2i["<pad>"]], dim=-1)

        # 2. Ouput shape for loss calculation must be of the form (BATCH_SIZE, NUM_WORDS, *)
        # Refer pytorch docs for more details
        loss = criterion(output.permute(0, 2, 1), y_true)

        # 3. Mask the loss. Needed since we have padding which is not needed
        # Can avoid if using pack_padded sequence?
        num_tokens = 0
        for i, yl in enumerate(ylens):
            loss[i, yl-1:] *= 0 # yl-1 to remove <sos>
            num_tokens += yl - 1

        # 4. SUM the losses then divide by number of tokens and finally call backward
        loss = loss.sum() / num_tokens
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 2)
        # Adjust parameters
        optimizer.step()
        if (batch_num + 1) % 10 == 0:
             print("Step: {} Loss: {}".format(batch_num + 1, loss.item()))
        total_loss += loss.item()
    print("EP: {} Loss: {}".format(i + 1, total_loss / len(dataloader)))
# Out:
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 459, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 10 Loss: 9.107857704162598
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 453, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 394, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 20 Loss: 9.115081787109375
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 359, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 30 Loss: 9.073039054870605
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 40 Loss: 9.069454193115234
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 448, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 50 Loss: 9.079089164733887
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 493, 50])
# Step: 60 Loss: 9.10810661315918
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 70 Loss: 9.087471008300781
# torch.Size([12, 500, 50])
# torch.Size([12, 395, 50])
# torch.Size([12, 425, 50])
# torch.Size([12, 451, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 408, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 80 Loss: 9.073866844177246
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 447, 50])
# Step: 90 Loss: 9.097003936767578
# torch.Size([12, 489, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 100 Loss: 9.126893043518066
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 110 Loss: 9.070479393005371
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 411, 50])
# Step: 120 Loss: 9.084700584411621
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 130 Loss: 9.066267967224121
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 484, 50])
# torch.Size([12, 445, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 140 Loss: 9.052245140075684
# torch.Size([12, 500, 50])
# torch.Size([12, 322, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 434, 50])
# torch.Size([12, 449, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 150 Loss: 9.062114715576172
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 290, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 391, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 160 Loss: 9.100448608398438
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 454, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 406, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 170 Loss: 9.120261192321777
# torch.Size([12, 374, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 493, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 180 Loss: 9.064817428588867
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 350, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 190 Loss: 9.088553428649902
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 457, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 366, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 200 Loss: 9.0752534866333
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 210 Loss: 9.04958438873291
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 220 Loss: 9.08234691619873
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 410, 50])
# torch.Size([12, 488, 50])
# torch.Size([12, 496, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 230 Loss: 9.093521118164062
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 482, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 240 Loss: 9.076544761657715
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 448, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 250 Loss: 9.094367980957031
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 429, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 260 Loss: 9.04958438873291
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 270 Loss: 9.105578422546387
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 280 Loss: 9.082962036132812
# torch.Size([12, 500, 50])
# torch.Size([12, 497, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 290 Loss: 9.105213165283203
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 485, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 481, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 300 Loss: 9.080850601196289
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 497, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 495, 50])
# torch.Size([12, 500, 50])
# Step: 310 Loss: 9.105217933654785
# torch.Size([12, 448, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 370, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 320 Loss: 9.077400207519531
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 371, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 330 Loss: 9.071647644042969
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 340 Loss: 9.095963478088379
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 469, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 350 Loss: 9.06324577331543
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 486, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 360 Loss: 9.104629516601562
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([4, 390, 50])
# EP: 4 Loss: 9.086527920548857
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 494, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 10 Loss: 9.090758323669434
# torch.Size([12, 500, 50])
# torch.Size([12, 422, 50])
# torch.Size([12, 410, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 494, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 20 Loss: 9.097352027893066
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 30 Loss: 9.07826042175293
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 448, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 478, 50])
# torch.Size([12, 500, 50])
# Step: 40 Loss: 9.095101356506348
# torch.Size([12, 497, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 50 Loss: 9.059663772583008
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 413, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 60 Loss: 9.088590621948242
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 476, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 70 Loss: 9.10262393951416
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 80 Loss: 9.088165283203125
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 485, 50])
# Step: 90 Loss: 9.072463035583496
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 461, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 457, 50])
# Step: 100 Loss: 9.092540740966797
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 435, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 486, 50])
# torch.Size([12, 500, 50])
# Step: 110 Loss: 9.10152816772461
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 120 Loss: 9.090981483459473
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 372, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 416, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 130 Loss: 9.107818603515625
# torch.Size([12, 442, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 495, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 460, 50])
# Step: 140 Loss: 9.083148956298828
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 456, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 374, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 150 Loss: 9.113280296325684
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 160 Loss: 9.098254203796387
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 488, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 170 Loss: 9.117594718933105
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 385, 50])
# torch.Size([12, 469, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 180 Loss: 9.077117919921875
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 190 Loss: 9.10181999206543
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 200 Loss: 9.096546173095703
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 210 Loss: 9.1103515625
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 408, 50])
# torch.Size([12, 500, 50])
# Step: 220 Loss: 9.095417022705078
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 230 Loss: 9.114092826843262
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 459, 50])
# torch.Size([12, 457, 50])
# Step: 240 Loss: 9.051200866699219
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 468, 50])
# torch.Size([12, 482, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 250 Loss: 9.072690963745117
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 446, 50])
# torch.Size([12, 462, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 260 Loss: 9.087859153747559
# torch.Size([12, 500, 50])
# torch.Size([12, 412, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 485, 50])
# torch.Size([12, 449, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 395, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 270 Loss: 9.080970764160156
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 423, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 492, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 454, 50])
# torch.Size([12, 500, 50])
# Step: 280 Loss: 9.047764778137207
# torch.Size([12, 500, 50])
# torch.Size([12, 446, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 408, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 290 Loss: 9.061473846435547
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 467, 50])
# torch.Size([12, 485, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 300 Loss: 9.11526870727539
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 439, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# Step: 310 Loss: 9.114808082580566
# torch.Size([12, 500, 50])
# torch.Size([12, 499, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 499, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# torch.Size([12, 500, 50])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f7f39e3af18d> in <module>()
#      33         # 4. SUM the losses then divide by number of tokens and finally call backward
#      34         loss = loss.sum() / num_tokens
# ---> 35         loss.backward()
#      36
#      37         torch.nn.utils.clip_grad_norm_(model.parameters(), 2)
#
# ~/anaconda3/envs/FNC/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/anaconda3/envs/FNC/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
xlens[0]
# Out:
# 188

# %%
i = 0

# %%
print(x[i][:xlens[i]])
# Out:
# tensor([10000,   635,   132,  1430, 10002,  4845,     6,  9918,    12,  1237,
#          3116,   167,     5,  5182,  2051,    43, 10002,   212, 10002,    11,
#           566,    57,     0,    77,     1,   262,    43,   346,    51,  6644,
#           105,  1143,  1841,   100, 10002,    15,   886,    12,    69, 10002,
#             4,     0,  3522,   860,    43, 10002,     0,   141,   567,     8,
#            42,    11,  3640,  5293, 10002,   103,  9803,   742,    11,    38,
#          1885, 10002,     4, 10002,    33,    22,  1352,     5,  9214,    33,
#            22,    28,  4883,    58,     2,   494,   126,   886,  1993,    10,
#          2040,     1,     0, 10002,    33, 10002,     3,   174,    54,  7994,
#           151,     0, 10002,   141,   314,    24,    22,     5,  5420,  8227,
#             4,    39,  7468,    18,     0,  8323,    42,   753,  1881,     9,
#           783,  1257,     4,    72,  1800,    80,     5,   197,     8,    11,
#             5, 10002, 10002,   439,    22,     5, 10002, 10002,   742,  1982,
#            22, 10002,  1158,     2,   960,    53,     1,     0,   197, 10002,
#         10002,   159,    29,    25,  1450,     1,    19,  1438,  2356,   312,
#          1095,   547,    47, 10002,     0,   172,  3878,  1143,     9,  6055,
#            53,     7,    39,   315,  1955,  9015, 10002,    42,    23,    19,
#           245,   563,     0, 10002,  6966, 10002,     4,     0,   797,     8,
#            34,  1502, 10002,  6186,     3, 10002, 10002, 10001],
#        device='cuda:0')

# %%
print(y[i][:ylens[i]])
# Out:
# tensor([10000,   473,  1143,  1841,   567,     8,    42,    11,    28,  4883,
#            58,     2,   494,   126,   886,  1993,    10,  2040,     1,     0,
#         10002,   737,     6, 10002,  1143,    16,     8,    42,    11,  1352,
#            20,     5,   351,     3,   287,     8, 10002,     4,   596,   439,
#            22,     5, 10002, 10002,    42,   753, 10002,   159,    29,    25,
#          1450,     1,    19,  1438,  2356,   312,  1095,   547,    47, 10002,
#         10001], device='cuda:0')

# %%
index2Sent(x[i, :xlens[i]].cpu().numpy(), i2w)
# Out:
# '<sos> ever since kangana <unk> remark on koffee with karan sparked off a nationwide debate about <unk> every <unk> has something or the other to say about it. when mid-day asked priyanka chopra what <unk> as someone with no <unk> in the industry, felt about <unk> the actor revealed that she has personally experienced <unk> said, "every star has their individual <unk> in <unk> i have faced a lot. i have been kicked out of films because someone else was recommended to the <unk> i <unk> and got over it." however, the <unk> actor does not have a bitter taste in her mouth from the experience. she added, "there is nothing wrong in being born into a family that has a <unk> <unk> don\'t have a <unk> <unk> star kids have <unk> pressure of living up to the family <unk> <unk> those who are meant to be success stories become that, despite all <unk> the work front, priyanka is gearing up for her big hollywood debut, <unk> she will be seen playing the <unk> victoria <unk> in the film, that also stars <unk> johnson and <unk> <unk> <eos>'

# %%
index2Sent(y[i, :ylens[i]].cpu().numpy(), i2w)
# Out:
# "<sos> actress priyanka chopra revealed that she has been kicked out of films because someone else was recommended to the <unk> speaking on <unk> priyanka said that she has faced it a lot and added that <unk> in bollywood don't have a <unk> <unk> she added, <unk> those who are meant to be success stories become that, despite all <unk> <eos>"

# %%
index2Sent(output.argmax(dim=-1)[i].cpu().numpy(), i2w)
# Out:
# '<unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>'

# %%
output.argmax(dim=-1)[-1]
# Out:
# tensor([10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002, 10002,
#         10002, 10002, 10002], device='cuda:0')

# %%
i2w[31]
